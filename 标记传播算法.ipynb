# %% [markdown]
# **SVD分解**
#
# 当数据已经中心化时，SVD分解等价于主成分分析，它主要起到一个降维的作用。
#
# 设X是秩为r的n×m矩阵，那么一定存在一个分块矩阵为对角矩阵D的n×m矩阵$\varSigma$，其中D的对角线元素是X的前r个非零奇异值。所谓奇异值，就是矩阵$X^T X$的特征值的平方根。并且存在一个n×n的正交矩阵U和一个m×m的正交矩阵V，使得：
#
# $$
# X = U\varSigma V^T
# $$
#
# 其中V是$X^T X$的特征向量阵，因为$\varSigma_x = \frac{1}{n-1}X^T X $,可以证明V也是协方差矩阵$\varSigma_x$的特征向量阵。
#
# 如果作变换$Y = XV$,可以证明：
#
# $$
# \varSigma_y = \frac{1}{n-1}Y^T Y = \frac{1}{n-1}\varSigma^T \varSigma
# $$
#
# 容易证明$\varSigma^T \varSigma/(n-1)$ 也正好是PCA中的特征根对角矩阵D,$D = diag(\lambda_1,\lambda_2,...,\lambda_m)$
#
# **标记传播算法**
#
# 标记传播算法的核心思想是，一个未标记数据的标签应该取决于周围的标签。具体实施的过程中，可以认为一个数据点成为某个标签的概率始终受到周围标签的灌输影响，但是已标签数据的标签始终不会改变。
#
# 设数据集为$f = [f_1 f_2 ... f_n]$，n是未标记数据点数目与已标记数据点数目的和，$f = f_{p×n}$，p是标签的数目(采用one-hot编码)。
#
# 设权重矩阵$W = [w_{ij}]$, 归一化矩阵$D = diag(d_{ij}),d = \Sigma_{j}w_{ij}$，$P = D^{-1}W$而
# $$
# w_{ij} =  exp(-\frac{\Sigma_k (x_{ik}-x_{jk})^2}{2\sigma^2})
# $$
#
# 执行标签传播，直到到达规定迭代次数或概率值变化足够小为止：
#
# $$
# f = Pf
# $$
#
# 然后，取同一个样本中收敛概率值最大的那个标签作为样本标签。

# %%
class market():
    def word_cut(self,documents,stopwords):
        import jieba
        texts = []
        for line in documents:
            words = ' '.join(jieba.cut(line)).split(' ') # 用空格去连接，连接后马上又拆分
            text = []
            for word in words:
                if (word not in stopwords) & (word != '')& (word != '\u3000')& (word != '\n')&(word != '\u200b'):
                    text.append(word)
            texts.append(text)
        return(texts)
    def frequency(self,texts,freq):
        from collections import defaultdict
        frequency = defaultdict(int) # value为int
        for text in texts:
            for word in text:
                frequency[word] += 1
        texts = [[word for word in text if frequency[word] > freq] for text in texts]
        return(texts)
    def regroup(self,texts):
        new_texts = []
        for i,sentence in enumerate(texts):
            new_texts.append(" ".join(sentence))
        return(new_texts)
    def add_stopwords(self,path):
        stopwords = set()
        file = open(path,'r',encoding = 'cp936')
        for line in file:
            stopwords.add(line.strip())
        file.close()
        return(stopwords)
    def Add_stopwords(self,path):
        stopwords = set()
        with open(path,'r',encoding = 'cp936') as file:
            for line in file:
                stopwords.add(line.strip())
        return(stopwords)

# %%
def navie_knn(dataSet, query, k):  
    # 计算出某一样本与所有样本的距离，选择最大(应该修改为最小？)的k个样本作为用于knn
    numSamples = dataSet.shape[0] # return row(sample) number of dataset
    
    ## step 1: calculate Euclidean distance  
    diff = np.tile(query, (numSamples, 1)) - dataSet #tile: 把query这个向量纵向复制，使得结果与dataset具有同样的行数
    squaredDiff = diff ** 2  
    squaredDist = np.sum(squaredDiff, axis = 1) # sum is performed by row  
  
    ## step 2: sort the distance  
    sortedDistIndices = np.argsort(squaredDist)   # numpy.argsort 返回的是数组值从小到大的索引值（注意是索引值，不是绝对值）
    if k > len(sortedDistIndices):  
        k = len(sortedDistIndices)  
  
    return sortedDistIndices[0:k]

# %%
# build a big graph (normalized weight matrix)  
def buildGraph(MatX, kernel_type, rbf_sigma = None, knn_num_neighbors = None):  
    num_samples = MatX.shape[0]  # return row(sample) number of MatX
    affinity_matrix = np.zeros((num_samples, num_samples), np.float32)  
    if kernel_type == 'rbf':  
        if rbf_sigma == None:  
            raise ValueError('You should input a sigma of rbf kernel!')  
        for i in range(num_samples):  
            row_sum = 0.0  
            for j in range(num_samples):  
                diff = MatX[i, :] - MatX[j, :]  
                affinity_matrix[i][j] = np.exp(sum(diff**2) / (-2.0 * rbf_sigma**2))  
                row_sum += affinity_matrix[i][j]  
            affinity_matrix[i][:] /= row_sum  
    elif kernel_type == 'knn':  
        if knn_num_neighbors == None:  
            raise ValueError('You should input a k of knn kernel!')  
        for i in range(num_samples):  
            k_neighbors = navie_knn(MatX, MatX[i, :], knn_num_neighbors)  
            affinity_matrix[i][k_neighbors] = 1.0 / knn_num_neighbors  # 将节点i与附近的k个节点连接起来，每个边的权重是1/knn_num_neighbors
    else:  
        raise NameError('Not support kernel type! You can use knn or rbf!')  
      
    return affinity_matrix

# %%
# label propagation  
def labelPropagation(Mat_Label, Mat_Unlabel, labels, kernel_type = 'rbf', rbf_sigma = 0.20, \
                    knn_num_neighbors = 10, max_iter = 500, tol = 1e-3):  
    # initialize  
    num_label_samples = Mat_Label.shape[0]  #已经标记的sample number
    num_unlabel_samples = Mat_Unlabel.shape[0]  #未标记的sample number
    num_samples = num_label_samples + num_unlabel_samples
    labels_list = np.unique(labels)  #有哪些label
    num_classes = len(labels_list)  #label的种类数
      
    MatX = np.vstack((Mat_Label, Mat_Unlabel))
    clamp_data_label = np.zeros((num_label_samples, num_classes), np.float32)  
    for i in range(num_label_samples):  
        clamp_data_label[i][labels[i]] = 1.0   #标记出每一个labelled sample的具体label是什么
      
    label_function = np.zeros((num_samples, num_classes), np.float32)  
    label_function[0 : num_label_samples] = clamp_data_label  
    label_function[num_label_samples : num_samples] = -1  
      
    # graph construction  
    affinity_matrix = buildGraph(MatX, kernel_type, rbf_sigma, knn_num_neighbors)  
      
    # start to propagation  
    iter = 0; pre_label_function = np.zeros((num_samples, num_classes), np.float32)  
    changed = np.abs(pre_label_function - label_function).sum()  
    while iter < max_iter and changed > tol:  
        if iter % 1 == 0:  
            print ("---> Iteration %d/%d, changed: %f" % (iter, max_iter, changed))
        pre_label_function = label_function  
        iter += 1  
          
        # propagation  
        label_function = np.dot(affinity_matrix, label_function)  
          
        # clamp  
        label_function[0 : num_label_samples] = clamp_data_label  
          
        # check converge  
        changed = np.abs(pre_label_function - label_function).sum()  
      
    # get terminate label of unlabeled data  
    unlabel_data_labels = np.zeros(num_unlabel_samples)  
    for i in range(num_unlabel_samples):  
        unlabel_data_labels[i] = np.argmax(label_function[i+num_label_samples]) #取出参数中元素最大值所对应的索引 
      
    return unlabel_data_labels

# %%
import numpy as np
import pandas as pd
import os
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD 
import sklearn

process = market()

# chdir = input("请输入工作路径，工作路径里面只能存放未标记数据、已标记数据和stopwords")
os.chdir("D:/Users/label")

unlabelled_data = pd.read_csv("未标记数据_v2.csv")
unlabelled_data["标记情况"] = "未标记"

labelled_data = pd.read_csv("已标记数据_v2.csv")
labelled_data["标记情况"] = "已标记"

stopwords = process.Add_stopwords("stopwords.txt")

# %%
labelled_data = labelled_data[["博文","标记情况"]]
labelled_data = labelled_data.dropna()

unlabelled_data = unlabelled_data[["博文","标记情况"]]
unlabelled_data = unlabelled_data.dropna()

all_data = pd.concat([labelled_data,unlabelled_data],axis = 0) 
all_data.head()
# Out:
#                                                   博文 标记情况
# 0  给好多人说了新年快乐说了新年祝福还没有给自己说过。新年快乐希望在2020年你可以学有所成重要...  已标记
# 1  2019开始倒数了哦原来小时候觉得很遥远的2020年就是明天了要说2019年我收获了什么呢？...  已标记
# 2  微信，QQ都是认识的人，没有办法发泄内心的不满，渐渐养成了不发朋友圈的习惯，但是自己变得越来...  已标记
# 3  现在已经对酒上瘾很严重每天这个点必须喝半杯而且一天喝水喝特别少大概就一瓶不到..我会不会得病...  已标记
# 4  这段时间每天睡得晚，起的晚，可恨没有好好吃早餐。会不会得病啊中午上一节男老师的尊巴舞，如果体...  已标记

# %%
docs = process.word_cut(all_data["博文"],stopwords)

docs = process.frequency(docs,5)

docs = process.regroup(docs)

docs[:2]
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\lenovo\AppData\Local\Temp\jieba.cache
# Loading model cost 0.629 seconds.
# Prefix dict has been built successfully.
# ['好多 说 新年快乐 说 新年 说 新年快乐 希望 2020 年 改变 决心 下定决心 做 努力 这才 希望 2020 年 身体健康 平平安安 得病 熬夜 吃 垃圾 点 外卖 身体 受 影响 小孩子 一天天 希望 2020 年 学会 独立 事情 做 害怕 胆子 希望 2020 年 开开心心 想 乱七八糟 事情 控制 情绪 身上 太 糟糕 状况 好好 做 做 做 想 做 做好 做 生活 距离 做事 千万 一点 生活 关系 希望 越来越 不好 希望 爱 家人 身体健康 平安 开心 加油 好好 努力 2020 年 瘦 独立 收起 全文 d',
#  '2019 倒数 小时候 2020 年 明天 要说 2019 年 收获 仔细 想想 收获 挺 少 年 月 来到 陌生 地方 大学 生活 2019 两年 环境 特别 敏感 喜欢 坏 情绪 发泄 身上 朋友 忽略 独立 特别 抑郁 种种 改变 想 摔 东西 想 想 哭 想 伤心 世界 喜欢 总 想着 讨厌 死 想着 出 一场 治 快点 死 掉 想过 方式 自杀 晚上 睡不着 想 睡觉 意识 时 高中 高考 放假 一大 二 说 短 短 几年 说 装 一点 快乐 家人 任性 有时候 闷 亲戚 邻居 不爱 说话 老师 同学 朋友 爱 笑 爱 闹 相处 相处 朋友 光 想着 忽略 朋友 一点 害怕 不到 中 安慰 鼓励 害怕 乐观 脑子 远离 告诉 其他人 光 想 害怕 不行 拼命 开心 伤心 难过 努力 安慰 有时候 还会 干 事情 只会 原因 感觉 全世界 做 地方 发泄 掉 真的 羡慕 说 始终 敢 写成 字 中 拼命 一点 快乐 快乐 好像 得病 好像 说 一大 推 废话 2020 年 活着 收起 全文 d']

# %%
# 文档向量化

tfidf = TfidfVectorizer().fit(docs)

tfidf_matrix = tfidf.fit_transform(docs)

# %%
# SVD降维

n_pick_topics = 400

lsa = TruncatedSVD(n_pick_topics) 

lsa.fit(tfidf_matrix)
print("数据的方差贡献率：{:.2f} %".format(lsa.explained_variance_ratio_.sum()*100))
# Out:
# 数据的方差贡献率：64.34 %

# %%
tfidf_matrix_SVD = lsa.fit_transform(tfidf_matrix)

# %%
# from sklearn.cluster import KMeans
# clf = KMeans(n_clusters = 10)
# clf = clf.fit(tfidf_vec_labelled)
# clf.cluster_centers_.shape
# Out:
# (10, 50)

# %%
labels = pd.read_csv("已标记数据_v2.csv")
labels = labels["是否担忧（1=担忧，0=不担忧）"]
labels = labels.dropna()
labels = np.array(labels)
labels=labels.astype(np.int16)
len(labels)
# Out:
# 523

# %%
tfidf_vec_labelled = tfidf_matrix_SVD[:len(labels)]
tfidf_vec_unlabelled = tfidf_matrix_SVD[len(labels):]
print(tfidf_vec_labelled.shape[0])
print(tfidf_vec_unlabelled.shape[0])
# Out:
# 523
# 2014

# %%
# label = clf.labels_
# LABEL = pd.DataFrame({"聚类结果":label})
# LABEL.to_excel("聚类结果.xlsx",header = True)

# %%
unlabel_data_labels=labelPropagation(tfidf_vec_labelled, tfidf_vec_unlabelled, labels, kernel_type = 'rbf', rbf_sigma = 0.20, \
                                     knn_num_neighbors = 25, max_iter = 500, tol = 1e-3)
# Out:
# ---> Iteration 0/500, changed: 4551.000000
# ---> Iteration 1/500, changed: 74.871811
# ---> Iteration 2/500, changed: 81.652756
# ---> Iteration 3/500, changed: 82.548035
# ---> Iteration 4/500, changed: 81.239960
# ---> Iteration 5/500, changed: 78.977745
# ---> Iteration 6/500, changed: 76.317284
# ---> Iteration 7/500, changed: 73.533554
# ---> Iteration 8/500, changed: 70.767059
# ---> Iteration 9/500, changed: 68.088936
# ---> Iteration 10/500, changed: 65.533150
# ---> Iteration 11/500, changed: 63.113388
# ---> Iteration 12/500, changed: 60.832310
# ---> Iteration 13/500, changed: 58.686577
# ---> Iteration 14/500, changed: 56.669769
# ---> Iteration 15/500, changed: 54.774067
# ---> Iteration 16/500, changed: 52.991173
# ---> Iteration 17/500, changed: 51.312859
# ---> Iteration 18/500, changed: 49.731194
# ---> Iteration 19/500, changed: 48.238796
# ---> Iteration 20/500, changed: 46.828751
# ---> Iteration 21/500, changed: 45.494713
# ---> Iteration 22/500, changed: 44.230942
# ---> Iteration 23/500, changed: 43.032131
# ---> Iteration 24/500, changed: 41.893463
# ---> Iteration 25/500, changed: 40.810596
# ---> Iteration 26/500, changed: 39.779503
# ---> Iteration 27/500, changed: 38.796570
# ---> Iteration 28/500, changed: 37.858479
# ---> Iteration 29/500, changed: 36.962219
# ---> Iteration 30/500, changed: 36.105019
# ---> Iteration 31/500, changed: 35.284363
# ---> Iteration 32/500, changed: 34.497902
# ---> Iteration 33/500, changed: 33.743546
# ---> Iteration 34/500, changed: 33.019314
# ---> Iteration 35/500, changed: 32.323441
# ---> Iteration 36/500, changed: 31.654232
# ---> Iteration 37/500, changed: 31.010191
# ---> Iteration 38/500, changed: 30.389874
# ---> Iteration 39/500, changed: 29.791983
# ---> Iteration 40/500, changed: 29.215313
# ---> Iteration 41/500, changed: 28.658699
# ---> Iteration 42/500, changed: 28.121119
# ---> Iteration 43/500, changed: 27.601589
# ---> Iteration 44/500, changed: 27.099209
# ---> Iteration 45/500, changed: 26.613115
# ---> Iteration 46/500, changed: 26.142529
# ---> Iteration 47/500, changed: 25.686703
# ---> Iteration 48/500, changed: 25.244934
# ---> Iteration 49/500, changed: 24.816566
# ---> Iteration 50/500, changed: 24.401007
# ---> Iteration 51/500, changed: 23.997673
# ---> Iteration 52/500, changed: 23.606033
# ---> Iteration 53/500, changed: 23.225555
# ---> Iteration 54/500, changed: 22.855778
# ---> Iteration 55/500, changed: 22.496258
# ---> Iteration 56/500, changed: 22.146553
# ---> Iteration 57/500, changed: 21.806265
# ---> Iteration 58/500, changed: 21.475018
# ---> Iteration 59/500, changed: 21.152454
# ---> Iteration 60/500, changed: 20.838224
# ---> Iteration 61/500, changed: 20.532028
# ---> Iteration 62/500, changed: 20.233540
# ---> Iteration 63/500, changed: 19.942482
# ---> Iteration 64/500, changed: 19.658577
# ---> Iteration 65/500, changed: 19.381544
# ---> Iteration 66/500, changed: 19.111164
# ---> Iteration 67/500, changed: 18.847176
# ---> Iteration 68/500, changed: 18.589371
# ---> Iteration 69/500, changed: 18.337528
# ---> Iteration 70/500, changed: 18.091444
# ---> Iteration 71/500, changed: 17.850908
# ---> Iteration 72/500, changed: 17.615761
# ---> Iteration 73/500, changed: 17.385830
# ---> Iteration 74/500, changed: 17.160892
# ---> Iteration 75/500, changed: 16.940847
# ---> Iteration 76/500, changed: 16.725510
# ---> Iteration 77/500, changed: 16.514719
# ---> Iteration 78/500, changed: 16.308369
# ---> Iteration 79/500, changed: 16.106289
# ---> Iteration 80/500, changed: 15.908382
# ---> Iteration 81/500, changed: 15.714497
# ---> Iteration 82/500, changed: 15.524520
# ---> Iteration 83/500, changed: 15.338331
# ---> Iteration 84/500, changed: 15.155832
# ---> Iteration 85/500, changed: 14.976906
# ---> Iteration 86/500, changed: 14.801449
# ---> Iteration 87/500, changed: 14.629375
# ---> Iteration 88/500, changed: 14.460592
# ---> Iteration 89/500, changed: 14.294998
# ---> Iteration 90/500, changed: 14.132492
# ---> Iteration 91/500, changed: 13.973021
# ---> Iteration 92/500, changed: 13.816480
# ---> Iteration 93/500, changed: 13.662802
# ---> Iteration 94/500, changed: 13.511904
# ---> Iteration 95/500, changed: 13.363718
# ---> Iteration 96/500, changed: 13.218164
# ---> Iteration 97/500, changed: 13.075203
# ---> Iteration 98/500, changed: 12.934740
# ---> Iteration 99/500, changed: 12.796731
# ---> Iteration 100/500, changed: 12.661094
# ---> Iteration 101/500, changed: 12.527788
# ---> Iteration 102/500, changed: 12.396749
# ---> Iteration 103/500, changed: 12.267923
# ---> Iteration 104/500, changed: 12.141260
# ---> Iteration 105/500, changed: 12.016680
# ---> Iteration 106/500, changed: 11.894172
# ---> Iteration 107/500, changed: 11.773677
# ---> Iteration 108/500, changed: 11.655140
# ---> Iteration 109/500, changed: 11.538533
# ---> Iteration 110/500, changed: 11.423789
# ---> Iteration 111/500, changed: 11.310867
# ---> Iteration 112/500, changed: 11.199739
# ---> Iteration 113/500, changed: 11.090358
# ---> Iteration 114/500, changed: 10.982691
# ---> Iteration 115/500, changed: 10.876699
# ---> Iteration 116/500, changed: 10.772330
# ---> Iteration 117/500, changed: 10.669566
# ---> Iteration 118/500, changed: 10.568383
# ---> Iteration 119/500, changed: 10.468720
# ---> Iteration 120/500, changed: 10.370548
# ---> Iteration 121/500, changed: 10.273844
# ---> Iteration 122/500, changed: 10.178593
# ---> Iteration 123/500, changed: 10.084728
# ---> Iteration 124/500, changed: 9.992252
# ---> Iteration 125/500, changed: 9.901121
# ---> Iteration 126/500, changed: 9.811317
# ---> Iteration 127/500, changed: 9.722809
# ---> Iteration 128/500, changed: 9.635557
# ---> Iteration 129/500, changed: 9.549560
# ---> Iteration 130/500, changed: 9.464764
# ---> Iteration 131/500, changed: 9.381174
# ---> Iteration 132/500, changed: 9.298765
# ---> Iteration 133/500, changed: 9.217493
# ---> Iteration 134/500, changed: 9.137348
# ---> Iteration 135/500, changed: 9.058307
# ---> Iteration 136/500, changed: 8.980349
# ---> Iteration 137/500, changed: 8.903444
# ---> Iteration 138/500, changed: 8.827591
# ---> Iteration 139/500, changed: 8.752762
# ---> Iteration 140/500, changed: 8.678926
# ---> Iteration 141/500, changed: 8.606083
# ---> Iteration 142/500, changed: 8.534210
# ---> Iteration 143/500, changed: 8.463281
# ---> Iteration 144/500, changed: 8.393280
# ---> Iteration 145/500, changed: 8.324201
# ---> Iteration 146/500, changed: 8.256008
# ---> Iteration 147/500, changed: 8.188716
# ---> Iteration 148/500, changed: 8.122280
# ---> Iteration 149/500, changed: 8.056685
# ---> Iteration 150/500, changed: 7.991933
# ---> Iteration 151/500, changed: 7.927993
# ---> Iteration 152/500, changed: 7.864875
# ---> Iteration 153/500, changed: 7.802547
# ---> Iteration 154/500, changed: 7.740995
# ---> Iteration 155/500, changed: 7.680194
# ---> Iteration 156/500, changed: 7.620167
# ---> Iteration 157/500, changed: 7.560870
# ---> Iteration 158/500, changed: 7.502306
# ---> Iteration 159/500, changed: 7.444446
# ---> Iteration 160/500, changed: 7.387295
# ---> Iteration 161/500, changed: 7.330838
# ---> Iteration 162/500, changed: 7.275058
# ---> Iteration 163/500, changed: 7.219941
# ---> Iteration 164/500, changed: 7.165483
# ---> Iteration 165/500, changed: 7.111676
# ---> Iteration 166/500, changed: 7.058501
# ---> Iteration 167/500, changed: 7.005952
# ---> Iteration 168/500, changed: 6.954021
# ---> Iteration 169/500, changed: 6.902695
# ---> Iteration 170/500, changed: 6.851954
# ---> Iteration 171/500, changed: 6.801799
# ---> Iteration 172/500, changed: 6.752239
# ---> Iteration 173/500, changed: 6.703235
# ---> Iteration 174/500, changed: 6.654794
# ---> Iteration 175/500, changed: 6.606912
# ---> Iteration 176/500, changed: 6.559562
# ---> Iteration 177/500, changed: 6.512745
# ---> Iteration 178/500, changed: 6.466455
# ---> Iteration 179/500, changed: 6.420683
# ---> Iteration 180/500, changed: 6.375425
# ---> Iteration 181/500, changed: 6.330667
# ---> Iteration 182/500, changed: 6.286398
# ---> Iteration 183/500, changed: 6.242612
# ---> Iteration 184/500, changed: 6.199316
# ---> Iteration 185/500, changed: 6.156487
# ---> Iteration 186/500, changed: 6.114125
# ---> Iteration 187/500, changed: 6.072228
# ---> Iteration 188/500, changed: 6.030768
# ---> Iteration 189/500, changed: 5.989767
# ---> Iteration 190/500, changed: 5.949194
# ---> Iteration 191/500, changed: 5.909050
# ---> Iteration 192/500, changed: 5.869337
# ---> Iteration 193/500, changed: 5.830043
# ---> Iteration 194/500, changed: 5.791162
# ---> Iteration 195/500, changed: 5.752687
# ---> Iteration 196/500, changed: 5.714619
# ---> Iteration 197/500, changed: 5.676939
# ---> Iteration 198/500, changed: 5.639662
# ---> Iteration 199/500, changed: 5.602755
# ---> Iteration 200/500, changed: 5.566231
# ---> Iteration 201/500, changed: 5.530090
# ---> Iteration 202/500, changed: 5.494306
# ---> Iteration 203/500, changed: 5.458897
# ---> Iteration 204/500, changed: 5.423834
# ---> Iteration 205/500, changed: 5.389133
# ---> Iteration 206/500, changed: 5.354788
# ---> Iteration 207/500, changed: 5.320780
# ---> Iteration 208/500, changed: 5.287111
# ---> Iteration 209/500, changed: 5.253773
# ---> Iteration 210/500, changed: 5.220775
# ---> Iteration 211/500, changed: 5.188093
# ---> Iteration 212/500, changed: 5.155735
# ---> Iteration 213/500, changed: 5.123697
# ---> Iteration 214/500, changed: 5.091971
# ---> Iteration 215/500, changed: 5.060551
# ---> Iteration 216/500, changed: 5.029437
# ---> Iteration 217/500, changed: 4.998630
# ---> Iteration 218/500, changed: 4.968113
# ---> Iteration 219/500, changed: 4.937898
# ---> Iteration 220/500, changed: 4.907965
# ---> Iteration 221/500, changed: 4.878315
# ---> Iteration 222/500, changed: 4.848952
# ---> Iteration 223/500, changed: 4.819858
# ---> Iteration 224/500, changed: 4.791038
# ---> Iteration 225/500, changed: 4.762497
# ---> Iteration 226/500, changed: 4.734223
# ---> Iteration 227/500, changed: 4.706210
# ---> Iteration 228/500, changed: 4.678459
# ---> Iteration 229/500, changed: 4.650966
# ---> Iteration 230/500, changed: 4.623727
# ---> Iteration 231/500, changed: 4.596733
# ---> Iteration 232/500, changed: 4.570000
# ---> Iteration 233/500, changed: 4.543500
# ---> Iteration 234/500, changed: 4.517246
# ---> Iteration 235/500, changed: 4.491223
# ---> Iteration 236/500, changed: 4.465447
# ---> Iteration 237/500, changed: 4.439893
# ---> Iteration 238/500, changed: 4.414576
# ---> Iteration 239/500, changed: 4.389485
# ---> Iteration 240/500, changed: 4.364622
# ---> Iteration 241/500, changed: 4.339972
# ---> Iteration 242/500, changed: 4.315543
# ---> Iteration 243/500, changed: 4.291337
# ---> Iteration 244/500, changed: 4.267336
# ---> Iteration 245/500, changed: 4.243557
# ---> Iteration 246/500, changed: 4.219977
# ---> Iteration 247/500, changed: 4.196609
# ---> Iteration 248/500, changed: 4.173445
# ---> Iteration 249/500, changed: 4.150469
# ---> Iteration 250/500, changed: 4.127708
# ---> Iteration 251/500, changed: 4.105131
# ---> Iteration 252/500, changed: 4.082758
# ---> Iteration 253/500, changed: 4.060567
# ---> Iteration 254/500, changed: 4.038571
# ---> Iteration 255/500, changed: 4.016770
# ---> Iteration 256/500, changed: 3.995146
# ---> Iteration 257/500, changed: 3.973706
# ---> Iteration 258/500, changed: 3.952445
# ---> Iteration 259/500, changed: 3.931369
# ---> Iteration 260/500, changed: 3.910463
# ---> Iteration 261/500, changed: 3.889748
# ---> Iteration 262/500, changed: 3.869187
# ---> Iteration 263/500, changed: 3.848798
# ---> Iteration 264/500, changed: 3.828586
# ---> Iteration 265/500, changed: 3.808540
# ---> Iteration 266/500, changed: 3.788667
# ---> Iteration 267/500, changed: 3.768944
# ---> Iteration 268/500, changed: 3.749384
# ---> Iteration 269/500, changed: 3.729993
# ---> Iteration 270/500, changed: 3.710746
# ---> Iteration 271/500, changed: 3.691657
# ---> Iteration 272/500, changed: 3.672736
# ---> Iteration 273/500, changed: 3.653955
# ---> Iteration 274/500, changed: 3.635328
# ---> Iteration 275/500, changed: 3.616853
# ---> Iteration 276/500, changed: 3.598530
# ---> Iteration 277/500, changed: 3.580350
# ---> Iteration 278/500, changed: 3.562310
# ---> Iteration 279/500, changed: 3.544410
# ---> Iteration 280/500, changed: 3.526663
# ---> Iteration 281/500, changed: 3.509056
# ---> Iteration 282/500, changed: 3.491580
# ---> Iteration 283/500, changed: 3.474243
# ---> Iteration 284/500, changed: 3.457038
# ---> Iteration 285/500, changed: 3.439972
# ---> Iteration 286/500, changed: 3.423041
# ---> Iteration 287/500, changed: 3.406234
# ---> Iteration 288/500, changed: 3.389556
# ---> Iteration 289/500, changed: 3.373012
# ---> Iteration 290/500, changed: 3.356598
# ---> Iteration 291/500, changed: 3.340306
# ---> Iteration 292/500, changed: 3.324140
# ---> Iteration 293/500, changed: 3.308092
# ---> Iteration 294/500, changed: 3.292176
# ---> Iteration 295/500, changed: 3.276370
# ---> Iteration 296/500, changed: 3.260695
# ---> Iteration 297/500, changed: 3.245126
# ---> Iteration 298/500, changed: 3.229680
# ---> Iteration 299/500, changed: 3.214344
# ---> Iteration 300/500, changed: 3.199129
# ---> Iteration 301/500, changed: 3.184022
# ---> Iteration 302/500, changed: 3.169025
# ---> Iteration 303/500, changed: 3.154155
# ---> Iteration 304/500, changed: 3.139382
# ---> Iteration 305/500, changed: 3.124718
# ---> Iteration 306/500, changed: 3.110161
# ---> Iteration 307/500, changed: 3.095718
# ---> Iteration 308/500, changed: 3.081378
# ---> Iteration 309/500, changed: 3.067139
# ---> Iteration 310/500, changed: 3.053002
# ---> Iteration 311/500, changed: 3.038973
# ---> Iteration 312/500, changed: 3.025045
# ---> Iteration 313/500, changed: 3.011220
# ---> Iteration 314/500, changed: 2.997485
# ---> Iteration 315/500, changed: 2.983855
# ---> Iteration 316/500, changed: 2.970330
# ---> Iteration 317/500, changed: 2.956882
# ---> Iteration 318/500, changed: 2.943549
# ---> Iteration 319/500, changed: 2.930295
# ---> Iteration 320/500, changed: 2.917151
# ---> Iteration 321/500, changed: 2.904089
# ---> Iteration 322/500, changed: 2.891127
# ---> Iteration 323/500, changed: 2.878254
# ---> Iteration 324/500, changed: 2.865471
# ---> Iteration 325/500, changed: 2.852768
# ---> Iteration 326/500, changed: 2.840163
# ---> Iteration 327/500, changed: 2.827643
# ---> Iteration 328/500, changed: 2.815215
# ---> Iteration 329/500, changed: 2.802857
# ---> Iteration 330/500, changed: 2.790600
# ---> Iteration 331/500, changed: 2.778416
# ---> Iteration 332/500, changed: 2.766319
# ---> Iteration 333/500, changed: 2.754318
# ---> Iteration 334/500, changed: 2.742388
# ---> Iteration 335/500, changed: 2.730536
# ---> Iteration 336/500, changed: 2.718775
# ---> Iteration 337/500, changed: 2.707084
# ---> Iteration 338/500, changed: 2.695471
# ---> Iteration 339/500, changed: 2.683940
# ---> Iteration 340/500, changed: 2.672486
# ---> Iteration 341/500, changed: 2.661120
# ---> Iteration 342/500, changed: 2.649821
# ---> Iteration 343/500, changed: 2.638594
# ---> Iteration 344/500, changed: 2.627443
# ---> Iteration 345/500, changed: 2.616364
# ---> Iteration 346/500, changed: 2.605369
# ---> Iteration 347/500, changed: 2.594437
# ---> Iteration 348/500, changed: 2.583591
# ---> Iteration 349/500, changed: 2.572796
# ---> Iteration 350/500, changed: 2.562085
# ---> Iteration 351/500, changed: 2.551446
# ---> Iteration 352/500, changed: 2.540870
# ---> Iteration 353/500, changed: 2.530373
# ---> Iteration 354/500, changed: 2.519940
# ---> Iteration 355/500, changed: 2.509568
# ---> Iteration 356/500, changed: 2.499262
# ---> Iteration 357/500, changed: 2.489026
# ---> Iteration 358/500, changed: 2.478852
# ---> Iteration 359/500, changed: 2.468748
# ---> Iteration 360/500, changed: 2.458705
# ---> Iteration 361/500, changed: 2.448736
# ---> Iteration 362/500, changed: 2.438826
# ---> Iteration 363/500, changed: 2.428977
# ---> Iteration 364/500, changed: 2.419194
# ---> Iteration 365/500, changed: 2.409468
# ---> Iteration 366/500, changed: 2.399804
# ---> Iteration 367/500, changed: 2.390208
# ---> Iteration 368/500, changed: 2.380664
# ---> Iteration 369/500, changed: 2.371180
# ---> Iteration 370/500, changed: 2.361760
# ---> Iteration 371/500, changed: 2.352397
# ---> Iteration 372/500, changed: 2.343096
# ---> Iteration 373/500, changed: 2.333846
# ---> Iteration 374/500, changed: 2.324655
# ---> Iteration 375/500, changed: 2.315527
# ---> Iteration 376/500, changed: 2.306445
# ---> Iteration 377/500, changed: 2.297420
# ---> Iteration 378/500, changed: 2.288461
# ---> Iteration 379/500, changed: 2.279555
# ---> Iteration 380/500, changed: 2.270704
# ---> Iteration 381/500, changed: 2.261902
# ---> Iteration 382/500, changed: 2.253156
# ---> Iteration 383/500, changed: 2.244464
# ---> Iteration 384/500, changed: 2.235816
# ---> Iteration 385/500, changed: 2.227229
# ---> Iteration 386/500, changed: 2.218691
# ---> Iteration 387/500, changed: 2.210210
# ---> Iteration 388/500, changed: 2.201768
# ---> Iteration 389/500, changed: 2.193384
# ---> Iteration 390/500, changed: 2.185047
# ---> Iteration 391/500, changed: 2.176757
# ---> Iteration 392/500, changed: 2.168529
# ---> Iteration 393/500, changed: 2.160351
# ---> Iteration 394/500, changed: 2.152210
# ---> Iteration 395/500, changed: 2.144118
# ---> Iteration 396/500, changed: 2.136071
# ---> Iteration 397/500, changed: 2.128075
# ---> Iteration 398/500, changed: 2.120131
# ---> Iteration 399/500, changed: 2.112230
# ---> Iteration 400/500, changed: 2.104377
# ---> Iteration 401/500, changed: 2.096570
# ---> Iteration 402/500, changed: 2.088801
# ---> Iteration 403/500, changed: 2.081091
# ---> Iteration 404/500, changed: 2.073416
# ---> Iteration 405/500, changed: 2.065778
# ---> Iteration 406/500, changed: 2.058189
# ---> Iteration 407/500, changed: 2.050657
# ---> Iteration 408/500, changed: 2.043154
# ---> Iteration 409/500, changed: 2.035698
# ---> Iteration 410/500, changed: 2.028289
# ---> Iteration 411/500, changed: 2.020922
# ---> Iteration 412/500, changed: 2.013595
# ---> Iteration 413/500, changed: 2.006312
# ---> Iteration 414/500, changed: 1.999059
# ---> Iteration 415/500, changed: 1.991860
# ---> Iteration 416/500, changed: 1.984694
# ---> Iteration 417/500, changed: 1.977573
# ---> Iteration 418/500, changed: 1.970492
# ---> Iteration 419/500, changed: 1.963446
# ---> Iteration 420/500, changed: 1.956445
# ---> Iteration 421/500, changed: 1.949483
# ---> Iteration 422/500, changed: 1.942562
# ---> Iteration 423/500, changed: 1.935669
# ---> Iteration 424/500, changed: 1.928822
# ---> Iteration 425/500, changed: 1.922008
# ---> Iteration 426/500, changed: 1.915235
# ---> Iteration 427/500, changed: 1.908501
# ---> Iteration 428/500, changed: 1.901805
# ---> Iteration 429/500, changed: 1.895144
# ---> Iteration 430/500, changed: 1.888518
# ---> Iteration 431/500, changed: 1.881927
# ---> Iteration 432/500, changed: 1.875379
# ---> Iteration 433/500, changed: 1.868863
# ---> Iteration 434/500, changed: 1.862386
# ---> Iteration 435/500, changed: 1.855936
# ---> Iteration 436/500, changed: 1.849526
# ---> Iteration 437/500, changed: 1.843147
# ---> Iteration 438/500, changed: 1.836814
# ---> Iteration 439/500, changed: 1.830503
# ---> Iteration 440/500, changed: 1.824236
# ---> Iteration 441/500, changed: 1.817994
# ---> Iteration 442/500, changed: 1.811782
# ---> Iteration 443/500, changed: 1.805613
# ---> Iteration 444/500, changed: 1.799466
# ---> Iteration 445/500, changed: 1.793366
# ---> Iteration 446/500, changed: 1.787293
# ---> Iteration 447/500, changed: 1.781244
# ---> Iteration 448/500, changed: 1.775236
# ---> Iteration 449/500, changed: 1.769255
# ---> Iteration 450/500, changed: 1.763306
# ---> Iteration 451/500, changed: 1.757388
# ---> Iteration 452/500, changed: 1.751502
# ---> Iteration 453/500, changed: 1.745654
# ---> Iteration 454/500, changed: 1.739830
# ---> Iteration 455/500, changed: 1.734037
# ---> Iteration 456/500, changed: 1.728269
# ---> Iteration 457/500, changed: 1.722539
# ---> Iteration 458/500, changed: 1.716838
# ---> Iteration 459/500, changed: 1.711165
# ---> Iteration 460/500, changed: 1.705524
# ---> Iteration 461/500, changed: 1.699907
# ---> Iteration 462/500, changed: 1.694326
# ---> Iteration 463/500, changed: 1.688764
# ---> Iteration 464/500, changed: 1.683234
# ---> Iteration 465/500, changed: 1.677733
# ---> Iteration 466/500, changed: 1.672262
# ---> Iteration 467/500, changed: 1.666823
# ---> Iteration 468/500, changed: 1.661408
# ---> Iteration 469/500, changed: 1.656013
# ---> Iteration 470/500, changed: 1.650660
# ---> Iteration 471/500, changed: 1.645322
# ---> Iteration 472/500, changed: 1.640013
# ---> Iteration 473/500, changed: 1.634733
# ---> Iteration 474/500, changed: 1.629482
# ---> Iteration 475/500, changed: 1.624255
# ---> Iteration 476/500, changed: 1.619055
# ---> Iteration 477/500, changed: 1.613879
# ---> Iteration 478/500, changed: 1.608725
# ---> Iteration 479/500, changed: 1.603602
# ---> Iteration 480/500, changed: 1.598505
# ---> Iteration 481/500, changed: 1.593434
# ---> Iteration 482/500, changed: 1.588385
# ---> Iteration 483/500, changed: 1.583358
# ---> Iteration 484/500, changed: 1.578365
# ---> Iteration 485/500, changed: 1.573395
# ---> Iteration 486/500, changed: 1.568444
# ---> Iteration 487/500, changed: 1.563520
# ---> Iteration 488/500, changed: 1.558617
# ---> Iteration 489/500, changed: 1.553748
# ---> Iteration 490/500, changed: 1.548891
# ---> Iteration 491/500, changed: 1.544068
# ---> Iteration 492/500, changed: 1.539265
# ---> Iteration 493/500, changed: 1.534482
# ---> Iteration 494/500, changed: 1.529724
# ---> Iteration 495/500, changed: 1.524979
# ---> Iteration 496/500, changed: 1.520277
# ---> Iteration 497/500, changed: 1.515583
# ---> Iteration 498/500, changed: 1.510913
# ---> Iteration 499/500, changed: 1.506277

# %%
acc = pd.DataFrame({"PREDICTED" : list(unlabel_data_labels)})
acc["PREDICTED"].value_counts()
#  acc.to_excel("第三次测试.xlsx",header = True)

# %%
# unlabels= unlabelled_data["是否担忧（1=担忧，0=不担忧）"]
# unlabels = unlabels.dropna()

# %%
# acc = pd.DataFrame({"PREDICTED" : list(unlabel_data_labels),"ACTUAL":unlabels})
# acc["PREDICTED"] = acc["PREDICTED"].apply(lambda r:"担忧" if r == 1 else "不担忧")
# acc["ACTUAL"] = acc["ACTUAL"].apply(lambda r:"担忧" if r == 1 else "不担忧")
# sklearn.metrics.confusion_matrix(acc["ACTUAL"], acc["PREDICTED"], labels=["担忧","不担忧"], sample_weight=None)
# acc.to_excel("RESULT.xlsx",header = True)
# Out:
# array([[17, 19],
#        [27, 95]], dtype=int64)
